# %%
from urllib.parse import quote_plus, urlencode
from urllib.request import urlopen, Request
import xml.etree.ElementTree as ET
import json
import pandas as pd
import numpy as np
import os
import glob
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df=pd.read_csv('number/법정동코드 전체자료.csv',encoding='cp949', sep='\t')
df.head()
# Out:
#         법정동코드           법정동명 폐지여부
# 0  1100000000          서울특별시   존재
# 1  1111000000      서울특별시 종로구   존재
# 2  1111010100  서울특별시 종로구 청운동   존재
# 3  1111010200  서울특별시 종로구 신교동   존재
# 4  1111010300  서울특별시 종로구 궁정동   존재

# %%
ind=[]
for i in range(len(df)):
    st=df['법정동명'][i].split(' ')
    if len(st)<=2:
        ind.append(i)
ind
# Out:
# [0,
#  1,
#  94,
#  179,
#  229,
#  332,
#  342,
#  399,
#  422,
#  503,
#  508,
#  548,
#  573,
#  597,
#  673,
#  716,
#  737,
#  765,
#  806,
#  810,
#  913,
#  937,
#  975,
#  1003,
#  1072,
#  1087,
#  1112,
#  1113,
#  1165,
#  1208,
#  1232,
#  1260,
#  1323,
#  1383,
#  1430,
#  1478,
#  1497,
#  1514,
#  1541,
#  1566,
#  1567,
#  1640,
#  1704,
#  1744,
#  1774,
#  1825,
#  1862,
#  1900,
#  1901,
#  1959,
#  1979,
#  2025,
#  2046,
#  2104,
#  2123,
#  2124,
#  2179,
#  2229,
#  2284,
#  2395,
#  2396,
#  2451,
#  2495,
#  2527,
#  2586,
#  2615,
#  2616,
#  2658,
#  2683,
#  2688,
#  2710,
#  2722,
#  2734,
#  2746,
#  2760,
#  2769,
#  2778,
#  2792,
#  2815,
#  2818,
#  2824,
#  2833,
#  2912,
#  2913,
#  2971,
#  3017,
#  3027,
#  3031,
#  3063,
#  3091,
#  3117,
#  3280,
#  3281,
#  3334,
#  3342,
#  3355,
#  3363,
#  3370,
#  3382,
#  3415,
#  3429,
#  3454,
#  3477,
#  3587,
#  3624,
#  3625,
#  3660,
#  3694,
#  3725,
#  3767,
#  3870,
#  3871,
#  3917,
#  3944,
#  3973,
#  4027,
#  4054,
#  4055,
#  4074,
#  4094,
#  4104,
#  4132,
#  4302,
#  4303,
#  4304,
#  4305,
#  4306,
#  4307,
#  4308,
#  4309,
#  4310,
#  4311,
#  4312,
#  4313,
#  4314,
#  4315,
#  4316,
#  4321,
#  4336,
#  4346,
#  4357,
#  4366,
#  4394,
#  4409,
#  4423,
#  4439,
#  4451,
#  4456,
#  4457,
#  4710,
#  4805,
#  5014,
#  5139,
#  5174,
#  5207,
#  5325,
#  5348,
#  5529,
#  5548,
#  5568,
#  5639,
#  5767,
#  5778,
#  5788,
#  5808,
#  5820,
#  5909,
#  5940,
#  5978,
#  5992,
#  6007,
#  6037,
#  6318,
#  6506,
#  6653,
#  6869,
#  6968,
#  7253,
#  7399,
#  7459,
#  7560,
#  7716,
#  7964,
#  8088,
#  8270,
#  8467,
#  8822,
#  8975,
#  9172,
#  9288,
#  9524,
#  9671,
#  9805,
#  9908,
#  10056,
#  10215,
#  10369,
#  10622,
#  10803,
#  10924,
#  10978,
#  10979,
#  11061,
#  11200,
#  11307,
#  11424,
#  11468,
#  11497,
#  11513,
#  11682,
#  11794,
#  11883,
#  12046,
#  12223,
#  12299,
#  12368,
#  12489,
#  12636,
#  12755,
#  12884,
#  12939,
#  13051,
#  13126,
#  13262,
#  13432,
#  13522,
#  13817,
#  13818,
#  13984,
#  14441,
#  14664,
#  14838,
#  15247,
#  15518,
#  15662,
#  15818,
#  15848,
#  15990,
#  16187,
#  16336,
#  16518,
#  16653,
#  16775,
#  16964,
#  16965,
#  17116,
#  17369,
#  17800,
#  18044,
#  18061,
#  18198,
#  18222,
#  18410,
#  18564,
#  18780,
#  18815,
#  18976,
#  19093,
#  19278,
#  19419,
#  19681,
#  19942,
#  20174,
#  20392,
#  20535,
#  20700,
#  20891,
#  21104,
#  21381,
#  21456,
#  21669,
#  21870,
#  22069,
#  22231,
#  22232,
#  22348,
#  22574,
#  22719,
#  22886,
#  22932,
#  22964,
#  23149,
#  23374,
#  23553,
#  23734,
#  23842,
#  23906,
#  24013,
#  24190,
#  24391,
#  24546,
#  24756,
#  24963,
#  25092,
#  25266,
#  25410,
#  25581,
#  25582,
#  25852,
#  25886,
#  25898,
#  26015,
#  26111,
#  26234,
#  26453,
#  26680,
#  26707,
#  26720,
#  26797,
#  26974,
#  27130,
#  27219,
#  27302,
#  27425,
#  27633,
#  27831,
#  27973,
#  28238,
#  28426,
#  28563,
#  28769,
#  28931,
#  29251,
#  29469,
#  29602,
#  29777,
#  29924,
#  30070,
#  30194,
#  30402,
#  30403,
#  30775,
#  30819,
#  30966,
#  31283,
#  31509,
#  31711,
#  31955,
#  32135,
#  32266,
#  32496,
#  32774,
#  32790,
#  32930,
#  33153,
#  33436,
#  33664,
#  34056,
#  34515,
#  34732,
#  34907,
#  35173,
#  35658,
#  35847,
#  36002,
#  36440,
#  36858,
#  37142,
#  37373,
#  37625,
#  37854,
#  38125,
#  38391,
#  38684,
#  38859,
#  39203,
#  39354,
#  39457,
#  39598,
#  39626,
#  39627,
#  39851,
#  40066,
#  40281,
#  40360,
#  40507,
#  40837,
#  41205,
#  41497,
#  41633,
#  41845,
#  41927,
#  41951,
#  42038,
#  42075,
#  42201,
#  42330,
#  42470,
#  42481,
#  42588,
#  42662,
#  42811,
#  42965,
#  43097,
#  43271,
#  43442,
#  43647,
#  43813,
#  43965,
#  44161,
#  44301,
#  44423,
#  44482,
#  44604,
#  44749,
#  44854,
#  44964,
#  45097,
#  45252,
#  45372,
#  45486,
#  45719,
#  45720,
#  45768,
#  45800,
#  45958,
#  46076,
#  46077,
#  46213]

# %%
df= df.iloc[ind]
df.reset_index(drop=True, inplace=True)

df=df[df['폐지여부']=='존재']

# %%
df.to_csv('result/법정동코드.csv')

# %%
len(df['법정동코드'].unique())
# Out:
# 269
