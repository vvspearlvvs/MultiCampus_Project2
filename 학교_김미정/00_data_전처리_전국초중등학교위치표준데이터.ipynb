# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 전체 코드 출력
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
school_data = pd.read_csv('../Data/학교_Data/전국초중등학교위치표준데이터.csv', encoding='euc-kr')
school_data.info()
school_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   학교ID      500 non-null    object
#  1   학교명       500 non-null    object
#  2   학교급구분     500 non-null    object
#  3   설립일자      500 non-null    object
#  4   설립형태      500 non-null    object
#  5   본교분교구분    500 non-null    object
#  6   운영상태      500 non-null    object
#  7   소재지지번주소   500 non-null    object
#  8   소재지도로명주소  500 non-null    object
#  9   시도교육청코드   500 non-null    int64
#  10  시도교육청명    500 non-null    object
#  11  교육지원청코드   500 non-null    int64
#  12  교육지원청명    500 non-null    object
#  13  생성일자      500 non-null    object
#  14  변경일자      500 non-null    object
#  15  위도        500 non-null    float64
#  16  경도        500 non-null    float64
#  17  데이터기준일자   500 non-null    object
#  18  제공기관코드    500 non-null    int64
#  19  제공기관명     500 non-null    object
# dtypes: float64(2), int64(3), object(15)
# memory usage: 78.2+ KB
#            학교ID          학교명 학교급구분        설립일자 설립형태 본교분교구분 운영상태  \
# 0    B000013333    진주외국어고등학교  고등학교  1970-12-26   사립     본교   운영
# 1    B000022925       용남고등학교  고등학교  1991-03-09   공립     본교   운영
# 2    B000010931        장곡중학교   중학교  2001-03-06   공립     본교   운영
# 3    B000011284        대정중학교   중학교  1946-11-08   공립     본교   운영
# 4    B000008177        안천중학교   중학교  1991-03-01   공립     본교   운영
# ..          ...          ...   ...         ...  ...    ...  ...
# 495  B000011177        양주중학교   중학교  1970-03-16   공립     본교   운영
# 496  B000009324        서천중학교   중학교  2011-03-01   공립     본교   운영
# 497  B000012550       성복고등학교  고등학교  2011-03-01   공립     본교   운영
# 498  B000011813  부산국제외국어고등학교  고등학교  2004-03-01   사립     본교   운영
# 499  B000008641        불로중학교   중학교  1991-03-01   공립     본교   운영
#
#                       소재지지번주소                   소재지도로명주소  시도교육청코드      시도교육청명  \
# 0       경상남도 진주시 일반성면 개암리 884   경상남도 진주시 일반성면 동부로 2014-6  9010000     경상남도교육청
# 1      충청남도 계룡시 신도안면 남선리 1278     충청남도 계룡시 신도안면 신도안1길 32  8140000     충청남도교육청
# 2         경상북도 칠곡군 석적읍 중리 246      경상북도 칠곡군 석적읍 남중리8길 13  8750000     경상북도교육청
# 3    제주특별자치도 서귀포시 대정읍 하모리 778   제주특별자치도 서귀포시 대정읍 비행장로 18  9290000  제주특별자치도교육청
# 4          서울특별시 금천구 독산동 1089        서울특별시 금천구 한내로 69-44  7010000    서울특별시교육청
# ..                        ...                        ...      ...         ...
# 495       경상남도 양산시 상북면 석계리 51     경상남도 양산시 상북면 양주마을2길 18  9010000     경상남도교육청
# 496       경기도 용인시 기흥구 서천동 796         경기도 용인시 기흥구 서천동로 7  7530000      경기도교육청
# 497       경기도 용인시 수지구 성복동 782        경기도 용인시 수지구 도마치로 92  7530000      경기도교육청
# 498    부산광역시 해운대구 우동 1025-127  부산광역시 해운대구 해운대로469번길 50-1  7150000    부산광역시교육청
# 499         대구광역시 동구 불로동 1010           대구광역시 동구 방천로5길 8  7240000    대구광역시교육청
#
#      교육지원청코드            교육지원청명        생성일자        변경일자         위도          경도  \
# 0    9051000       경상남도진주교육지원청  2013-11-29  2020-09-22  35.169656  128.281668
# 1    8222000     충청남도논산계룡교육지원청  2013-11-29  2020-09-22  36.294309  127.244765
# 2    8941000       경상북도칠곡교육지원청  2013-11-29  2020-09-22  36.073455  128.415088
# 3    9299000  제주특별자치도서귀포시교육지원청  2013-11-29  2020-09-22  33.219962  126.253233
# 4    7041000      서울특별시남부교육지원청  2013-11-29  2020-09-22  37.459524  126.887499
# ..       ...               ...         ...         ...        ...         ...
# 495  9151000       경상남도양산교육지원청  2013-11-29  2020-09-22  35.415177  129.067757
# 496  7751000        경기도용인교육지원청  2013-11-29  2020-09-22  37.240019  127.075895
# 497  7751000        경기도용인교육지원청  2013-11-29  2020-09-22  37.323363  127.061123
# 498  7211000     부산광역시해운대교육지원청  2013-11-29  2020-09-22  35.165919  129.144358
# 499  7251000      대구광역시동부교육지원청  2013-11-29  2020-09-22  35.898301  128.634412
#
#         데이터기준일자   제공기관코드    제공기관명
# 0    2021-03-25  7001220  한국교원대학교
# 1    2021-03-25  7001220  한국교원대학교
# 2    2021-03-25  7001220  한국교원대학교
# 3    2021-03-25  7001220  한국교원대학교
# 4    2021-03-25  7001220  한국교원대학교
# ..          ...      ...      ...
# 495  2021-03-25  7001220  한국교원대학교
# 496  2021-03-25  7001220  한국교원대학교
# 497  2021-03-25  7001220  한국교원대학교
# 498  2021-03-25  7001220  한국교원대학교
# 499  2021-03-25  7001220  한국교원대학교
#
# [500 rows x 20 columns]
