# %%
import pandas as pd

# %%
subway_list = pd.read_csv('../Data/주변환경_Data/원본_전국도시철도역사정보표준데이터.csv',encoding='euc-kr')

# %%
subway_list
# Out:
#        역번호     역사명   노선번호          노선명                 영문역사명        한자역사명  \
# 0     3122   부평삼거리  S2801    인천지하철 1호선      Bupyeongsamgeori        富平三거리
# 1     3123   간석오거리  S2801    인천지하철 1호선         Ganseogogeori        間石五거리
# 2     3124    인천시청  S2801    인천지하철 1호선     Incheon City Hall         仁川市廳
# 3     3125    예술회관  S2801    인천지하철 1호선           Arts Center         藝術會館
# 4     3126   인천터미널  S2801    인천지하철 1호선  Incheon Bus Terminal        仁川터미널
# ...    ...     ...    ...          ...                   ...          ...
# 1010  4134    송파나루  S1109  서울 도시철도 9호선            Songpanaru         松坡나루
# 1011  4135    한성백제  S1109  서울 도시철도 9호선       Hanseong Baekje         漢城百?
# 1012  4136   올림픽공원  S1109  서울 도시철도 9호선          Olympic Park  올림픽公園(韓國體大)
# 1013  4137    둔촌오륜  S1109  서울 도시철도 9호선         Dunchon Oryun         遁村五輪
# 1014  4138  중앙보훈병원  S1109  서울 도시철도 9호선    VHS Medical Center       中央報?病院
#
#      환승역구분 환승노선번호        환승노선명        역위도         역경도   운영기관명  \
# ...

# %%
subway_list.drop(["영문역사명", "한자역사명", "역사전화번호", "데이터기준일자"], axis=1,inplace=True)

# %%
subway_list
# Out:
#        역번호     역사명   노선번호          노선명 환승역구분 환승노선번호        환승노선명        역위도  \
# 0     3122   부평삼거리  S2801    인천지하철 1호선   일반역      -            -  37.478267
# 1     3123   간석오거리  S2801    인천지하철 1호선   일반역      -            -  37.466921
# 2     3124    인천시청  S2801    인천지하철 1호선   일반역      -            -  37.457615
# 3     3125    예술회관  S2801    인천지하철 1호선   일반역      -            -  37.449334
# 4     3126   인천터미널  S2801    인천지하철 1호선   일반역      -            -  37.441917
# ...    ...     ...    ...          ...   ...    ...          ...        ...
# 1010  4134    송파나루  S1109  서울 도시철도 9호선   일반역    NaN          NaN  37.510120
# 1011  4135    한성백제  S1109  서울 도시철도 9호선   일반역    NaN          NaN  37.516865
# 1012  4136   올림픽공원  S1109  서울 도시철도 9호선   환승역  S1105  서울 도시철도 5호선  37.516088
# 1013  4137    둔촌오륜  S1109  서울 도시철도 9호선   일반역    NaN          NaN  37.517975
# 1014  4138  중앙보훈병원  S1109  서울 도시철도 9호선   일반역    NaN          NaN  37.529614
#
# ...

# %%
subway_list.to_csv("../Data/주변환경_Data/수정본_전국지하철역정보.csv")
