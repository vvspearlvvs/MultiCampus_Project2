# %%
## 네이버 카페에서 '과외', '과외추천', '과외추천해주세요' 등 검색 
## 지역은 카페명에서 추출해서 "지역별 과외수요"를 알아볼 수 있음 

## https://section.cafe.naver.com/ca-fe/home/search/articles?q=%EA%B3%BC%EC%99%B8%EC%B6%94%EC%B2%9C&p=3

# %%
import requests
import json
import pandas as pd 

import os
import sys

from urllib.parse import quote

import re

# %% [markdown]
# ## Test1..전체 카페에서 "과외추천해주세요" 검색하기
# ### 문제 : 카페명으로 지역을 어떻게 구분할 것인가?

# %%
client_id = "vD02ixj_z1lpFZ41CeO1"
client_secret = "qk2B9tKmJK"

def cafe_call(keyword,start):
    encText = quote(keyword)
    url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText+"&sort=date&display=100&start="+str(start) # json 결과
    '''
    요청변수 옵션
    - display : 검색결과 출력건수 (10,100)
    - start : 검색시작위치 (1,1000)
    - sort : 정렬옵션 (sim:유사도순, date:날짜순)
    '''
    result = requests.get(url=url, headers={"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    
    if result.status_code == 200:
        #data = json.loads(result.text)
        return result.json()
    else:
        print("error",result.status_code)
    
    '''
    출력결과 옵션
    - lastBuildDate : 검색결과를 생성한 시간 
    - total : 검색결과 문서의 총 개수 (ex : 강남구 과외추천 검색시 2,587)
    - start : 결과문서 중 문서의 시작점-> 한페이지에 100개씩 보여주니까 전체결과가 아님
    - display : 현재 검색결과로 보여준 결과개수 -> items dict안에 들어가는 최대
    - items : 개별검색결과
        - title : 카페 게시글 제목 -> 태그처리필요
        - link : 게시글 링크
        - description : 카페글 요약 -> 태그처리필요
        - cafename : 카페명
        - cafeurl : 카페링크
    
    # 4년치
    
    모든 문서 검색하려고 cafe_call 반복하기?
    # 출처 https://john-analyst.medium.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8%EC%9D%98-%ED%8A%B9%EC%A0%95-%ED%82%A4%EC%9B%8C%EB%93%9C-%ED%81%AC%EB%A1%A4%EB%A7%81%ED%95%98%EA%B8%B0-2c4644001144
    '''

# %%
#1000개의 키워드 검색 결과를 받아오기
def get1000results(keyword):
    list = []
    for num in range(0,10):
        list = list + cafe_call(keyword, num * 100 + 1)['items'] # list 안에 키값이 ’item’인 애들만 넣기
    return list

# %%
#키워드로 검색한결과
def getDataFrame():
    list = []
    result1 = get1000results("과외추천해주세요")
    result2 = get1000results("과외추천받아요")

    list = list + result1+result2
    
    df = pd.DataFrame.from_records(list)
    df.to_csv("./cafe_data.csv",encoding = 'utf-8-sig')
    
    return df

# %%
# main
df = getDataFrame()
df.head()
# Out:
#                                                title  \
# 0  전주 완산구 평화동 예비 초등 영어<b>과외</b> 삼천동 중등 국어<b>과외</b...
# 1  전주 완산구 동서학동 예비 초등 영어<b>과외</b> 서서학동 중등 국어<b>과외<...
# 2  전주 완산구 중앙동 예비 초등 영어<b>과외</b> 풍남동 중등 국어<b>과외</b...
# 3                                   안녕하세요^^가입인사드립니다.
# 4                        초등 국어나 수학 <b>과외 추천해주세요</b>~
#
#                                        link  \
# 0     http://cafe.naver.com/kts9719/2792736
# 1     http://cafe.naver.com/kts9719/2792729
# 2     http://cafe.naver.com/kts9719/2792725
# 3  http://cafe.naver.com/songdoeduall/36394
# 4     http://cafe.naver.com/pinklonos/62366
#
#                                          description                 cafename  \
# 0  평화동생물1<b>과외</b> 평화동생물Ⅰ<b>과외</b> 평화동생물2<b>과외</b...  닥공사★9급공무원,7급공무원,경찰,소...
# 1  <b>과외</b> 동서학동생물Ⅰ<b>과외</b> 동서학동생물2<b>과외</b> 동서...  닥공사★9급공무원,7급공무원,경찰,소...
# 2  중앙동생물1<b>과외</b> 중앙동생물Ⅰ<b>과외</b> 중앙동생물2<b>과외</b...  닥공사★9급공무원,7급공무원,경찰,소...
# 3  건전한 카페 문화를 위해 회원님들과 대화 시 존댓말을 사용해 <b>주세요</b>. ...                    송도에듀올
# 4                                   1:1 이였으면 좋겠어요 ~~                 해남맘 우먼파워
#
#                                cafeurl
# 0       https://cafe.naver.com/kts9719
# 1       https://cafe.naver.com/kts9719
# 2       https://cafe.naver.com/kts9719
# 3  https://cafe.naver.com/songdoeduall
# 4     https://cafe.naver.com/pinklonos

# %%
text = "전주 완산구 중앙동 예비 초등 영어<b>과외</b> 풍남동 중등 국어<b>과외</b>"
text2 = re.sub('[<b>|</b>]','',text)
text2
# Out:
# '전주 완산구 중앙동 예비 초등 영어과외 풍남동 중등 국어과외'

# %%
## title, description에 <b>,</b> 제거하기 
def clean_letter(x):
    x= re.sub('[<b>|</b>]','',x)
    return x

df['title'] = df['title'].apply(lambda x: re.sub('[<b>|</b>]',' ',x))
df['description'] = df['description'].apply(lambda x: re.sub('[<b>|</b>]',' ',x))

df.head()
# Out:
#                                                title  \
# 0  전주 완산구 평화동 예비 초등 영어   과외     삼천동 중등 국어   과외   ...
# 1  전주 완산구 동서학동 예비 초등 영어   과외     서서학동 중등 국어   과외 ...
# 2  전주 완산구 중앙동 예비 초등 영어   과외     풍남동 중등 국어   과외   ...
# 3                                   안녕하세요^^가입인사드립니다.
# 4                        초등 국어나 수학    과외 추천해주세요    ~
#
#                                        link  \
# 0     http://cafe.naver.com/kts9719/2792736
# 1     http://cafe.naver.com/kts9719/2792729
# 2     http://cafe.naver.com/kts9719/2792725
# 3  http://cafe.naver.com/songdoeduall/36394
# 4     http://cafe.naver.com/pinklonos/62366
#
#                                          description                 cafename  \
# 0  평화동생물1   과외     평화동생물Ⅰ   과외     평화동생물2   과외   ...  닥공사★9급공무원,7급공무원,경찰,소...
# 1     과외     동서학동생물Ⅰ   과외     동서학동생물2   과외     동서...  닥공사★9급공무원,7급공무원,경찰,소...
# 2  중앙동생물1   과외     중앙동생물Ⅰ   과외     중앙동생물2   과외   ...  닥공사★9급공무원,7급공무원,경찰,소...
# 3  건전한 카페 문화를 위해 회원님들과 대화 시 존댓말을 사용해    주세요    . ...                    송도에듀올
# 4                                   1:1 이였으면 좋겠어요 ~~                 해남맘 우먼파워
#
#                                cafeurl
# 0       https://cafe.naver.com/kts9719
# 1       https://cafe.naver.com/kts9719
# 2       https://cafe.naver.com/kts9719
# 3  https://cafe.naver.com/songdoeduall
# 4     https://cafe.naver.com/pinklonos

# %%
## cafename에 지역구 이름 있는거 찾기-> 새로운컬럼 지역!

gu = ['강서','강동','강남','강북','송도','해남','광명','목동']

# %%
df.groupby('cafename').count()
# Out:
#                            title  link  description  cafeurl
# cafename
# !▷중정공☞ 중국유학생활,중국여행,무...        1     1            1        1
# "시크먼트" 명품 정보 커뮤니티 - 샤넬...      3     3            3        3
# "예쁜카페 예카" 예쁜그릇과앤틱로모노...        3     3            3        3
# &lt;속초대표맘카페&gt;속대맘카페           1     1            1        1
# &lt;오행공&gt; 오산맘들의 행복한 공간       1     1            1        1
# ...                          ...   ...          ...      ...
# 홍천 엄마 사랑                       1     1            1        1
# 화도사랑                           1     1            1        1
# 황인영 영어 카페                     18    18           18       18
# 힐링cafe /고민 해결/힘든일 얘기해요...      2     2            2        2
# 힐스테이트 태전 통합 커뮤니티               3     3            3        3
#
# [428 rows x 4 columns]

# %% [markdown]
# ## Test2..몇가지 카페에서 '과외추천' 게시글 검색하기?

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import csv 

def get_cafe_url(url):
    # webdriver 객체 생성
    driver = webdriver.Chrome('./chromedriver')

    # 페이지 접근
    # 날짜지정, 검색어지정, 50개씩보이기
    #url="https://cafe.naver.com/hikicks?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=12946579%26search.media=0%26search.searchdate=2016-01-012021-09-13%26search.defaultValue=1%26userDisplay=50%26search.option=0%26search.sortBy=date%26search.searchBy=1%26search.query=%B0%FA%BF%DC%C3%DF%C3%B5%26search.viewtype=title%26search.page=1"    #print(url)
    driver.get(url)
    driver.switch_to.frame('cafe_main')

    soup = bs(driver.page_source ,'html.parser')
    soup = soup.find_all(class_ = 'article-board m-tcol-c')[1]# 네이버 카페 구조 확인후 게시글 내용만 가저오기
    #datas = soup.find_all('td', class_ = 'td_article')

    datas_list=[]
    datas = soup.find_all(class_ = 'td_article')
    for data in datas:
        article_title = data.find(class_ = 'article')
        #link = article_title.get('href')
        article_title = article_title.get_text().strip()
        print(article_title)
        datas_list.append(article_title)
        
        #print(article_title)
        #print(baseurl + link)

        #f = open('cafe5.csv', 'a+', newline='', encoding = "euc-kr")# 문자 인코딩 -> euc-kr 형태로 변경하여 사용. 안되면 utf-8로 변경 후 진행
        #wr = csv.writer(f)
        #wr.writerow([article_title])
        #f.close()  
    return datas_list

# %%
import pandas as pd
from urllib.parse import urlencode,quote
from datetime import datetime

keyword = "과외추천"
#query=%B0%FA%BF%DC%C3%DF%C3%B5%26
today_date = datetime.today().strftime("%Y-%m-%d")

df_fin = pd.DataFrame()
for pg in range(1,2):
    url = "https://cafe.naver.com/hikicks?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=12946579%26search.media=0%26search.searchdate=2016-01-012021-09-13%26search.defaultValue=1%26search.exact=%26search.include=%26userDisplay=50%26search.exclude=%26search.option=0%26search.sortBy=date%26search.searchBy=1%26search.includeAll=%26search.query=%B0%FA%BF%DC%C3%DF%C3%B5%26search.viewtype=title%26search.page="+str(pg)
    data_list = get_cafe_url(url)
    
    df = pd.DataFrame(data_list,columns=['article_title'])
    df_fin = pd.concat([df_fin,df],axis=0,ignore_index=True)

#df_fin.head()
filename = today_date+'-cafe_crawling.csv'  
df_fin.to_csv('./'+filename,encoding='utf-8-sig')
# Out:
# https://cafe.naver.com/hikicks?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=12946579%26search.media=0%26search.searchdate=2016-01-012021-09-13%26search.defaultValue=1%26search.exact=%26search.include=%26userDisplay=50%26search.exclude=%26search.option=0%26search.sortBy=date%26search.searchBy=1%26search.includeAll=%26search.query=%B0%FA%BF%DC%C3%DF%C3%B5%26search.viewtype=title%26search.page=1
# 의정부동 가능동 과학과외 흥선동 물리과외 과학과외 선생님 추천
# 원주 명륜동 고등 영어과외 개운동 중등 수학과외 추천 원주고 단구중 내신 대비
# 온라인과외 (수학) 추천좀 해주세요
# [추천]
#
#
#
#
#
#                                     초중고등생 영어과외 교재 추천 드립니다. ^^
# [인천] 인천 서구 가정고 고등 수학 석남중 가좌중 중등 영어 초등 국어 내신 과외 추천
# [인천] 인천 서구 청라국제도시 해원고 청라고 고등 수학 초은중 중등 영어 도담초 초등 국어 과외 추천
# 비대면 과외 추천드립니다
# 봉림동 오픽과외 신호동 토익과외 일대일 텝스 아이엘츠 영어쌤 추천
# [수완지구] 장덕고 명진고 고실중 성덕중 장덕초 논술 영어 국어 수학 내신 과외 추천
# 율하 오픽과외 장유 토익과외 일대일 텝스 아이엘츠 영어쌤 추천
# [인천] 해송고 신송고 박문여고 신송중 박문중 해송중 송명초 해송초 내신 전문 과목별 과외 추천
# [인천] 동춘 선학 연수동 중등 수학 고등 영어 논술 과외 학원 추천 과목별 내신관리 코칭
# [수지구] 신봉마을 신정마을 고등 수학 성동마을 버들치마을 중등 영어 과외 학원 추천
# [미사지구] 하남고 미사고 고등 영어 강동중 미사중 중등 수학 국어 학원 내신 과외 추천
# 남양주 직장인 토익 토플 학생 영어과외 주부 생활영어 공부 추천
# 율하과외 초등 중학생 고등 영어과외 국어 한국사 역사 수학과외 과학 완전 추천
# 한양수자인성남마크뷰 학군 하원초 금광중 대원중 숭신여중 숭신여고 과외 학원 추천
# 독일어과외 독일어과 새내기들에게 추천합니다~!
# 달방동 오픽과외 구호동 토익과외 일대일 텝스 아이엘츠 영어쌤 추천
# 강남토플학원추천 소수정예 그룹과외 클래스로!
# 구미과외 전문 수학과외 영수 외 한국사 과학 논술 학원 사회 영어 국어과외 추천
# 관악구과외 초등 중등 추천 수학과외 국어 한국사 과학 레슨 예비고 영어과외
# 율하동 영어과외 중학생 고등학생 수학과외 추천 실력있는 개인별 학습지도 고등학교 중학교
# 소수정예 그룹과외 아이엘츠어학원추천~!~!
# 진천과외 진천읍 중등 수학과외 읍내리 고등 영어과외 추천
# 반여동 한글방문 재송동 센텀 6세 7세 초등 한글1:1과외 학습지와는 다른 수업 추천
# 청림동 방문 과외 관악 초5 초6 국어과외 행운동 고3 고2 영어과외 초등 중학생 고등 낙성대 중2 중3 수학과외 추천 (이과) 중1 사탐 고1 과탐 내신대비 초3 전과목 초4 원격 수업도 가능 (온라인)
# 남현동 방문 과외 대학동 초5 국어과외 미성동 고2 영어과외 초등 중학생 고등 보라매동 중3 수학과외 추천 (이과) 사탐 과탐 내신대비 전과목 원격 수업도 가능 (온라인)
# 관악구 방문 과외 낙성대 초5 국어과외 난곡동 고2 영어과외 초등 중학생 고등 난향동 중3 수학과외 추천 (이과) 사탐 과탐 내신대비 전과목 원격 수업도 가능 (온라인)
# 도화과외 송림 중등 고등 국어 수학과외 과학 한국사 영어과외 일대일 학습 추천
# 당산동과외 양평동 중등 고등 수학과외 한국사 국어 개인지도 영어과외 체계적 학습 추천
# 부산 수학과외 안락동 중등 영어과외 명장동 고등 국어과외 지니쌤 추천!!
# 아이엘츠어학원추천 아이엘츠도 맞춤 과외로 배우자
# 진천 수학과외 중등 고등 영어과외 증평 초등 국어과외 추천
# 강남역 강남러시아어학원 학원강의와 화상강의&과외 배우기 추천
# 익산 부송동 국영수 영등동 초등 중등 고등 전문 개인과외 추천
# 서울 과외 성북구과외 길음동 영어쌤 돈암동 수학쌤 영어과외 수학과외 추천
# 포항과외 포항시과외 전문과외 박쌤이 추천하는 교육플랜! 방문과외부터 화상과외까지! 일대일 수준별 학습~!
# 요즘 수학과외 교재로 뭐 많이 쓰고 있나요? 수학의 정석 개념원리 등 추천해주세요^^
# 시흥시 국영수 1:1 개인과외 선생님 추천!
# 아이엘츠학원추천 아이엘츠도 맞춤 과외로 배워보세요
# 태국어학원 후기 추천/유학ㆍ취업준비 강남역 5분학원에서 과외ㆍ정규강의
# 아이엘츠학원추천 맞춤 과외로 확실하게 배우는 아이엘츠
# 아이엘츠어학원추천 아이엘츠도 맞춤 과외로 확실하게!
# 강서구 염창동 내발산동 등촌동 가양동 초등학생 중학생 고등학생 과외 학원 공부방 인강 추천 으로 고민중이세요?
# 야당동성인영어회화 동패동직장인영어회화 주부회화 토익영어과외 추천드립니다!
# 동대문 휘경동 수힉과외 고등학생 이문동 영어과외 중학생 온라인 대비 초등 휘경중 휘봉고 시험 개학준비 추천
# SAT어학원추천 SAT도 맞춤 과외로 확실하게 배우자!
# 어려운 SAT시험, 어떻게 공부해야할지 막막하다면? SAT과외추천 합니다!!!
# 동작구 / 관악구 / No.1과외천사 전문과외 추천~!!

# %% [markdown]
# ## Test3..'훈장마을'에서 지역별 채용정보 검색하기

# %%
# !pip uninstall html_table_parser
# Out:
# ^C

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import csv 
from html_table_parser import parser_functions as parser

def get_hunjang(url,pg):
    # webdriver 객체 생성
    driver = webdriver.Chrome('./chromedriver')
    
    # 페이지 접근
    driver.get(url)
    soup = bs(driver.page_source ,'html.parser')
    
    soup = soup.find(class_ = 's-adBn-wrap')#채용정보
    if pg <=1 :
        soup = soup.find_all(class_ = 'adRc-inner')[5] #1:스페셜, 2:포커스 3:플러스 4:리스트 5일반
    else:
        soup = soup.find_all(class_ = 'adRc-inner')[0] #1:스페셜, 2:포커스 3:플러스 4:리스트 5일반

    table = soup.find('table', class_='retbl-col')
    rows = table.find_all('tr')
    
    datas_list=[]
    for idx,tr in enumerate(rows):
        result={}
        if idx>0:
            tds = tr.find_all('td')
            result['academy_name'] = tds[1].text.rstrip()
            result['title'] = tds[2].text.strip()
            result['local'] = tds[3].text.rstrip().split("\n")[1]
            result['subject']=tds[3].text.rstrip().split("\n")[2]
            
            result['start_date'] = tds[4].text
            result['end_date'] = tds[5].text
            datas_list.append(result)
                   
    return datas_list

# %%
url1 = "https://www.hunjang.com/adopt/adopt_total_list.asp?schSubject=01&schSubject_name=%B1%B9%BE%EE&schSubject=02&schSubject_name=%BF%B5%BE%EE&schSubject=03&schSubject_name=%BC%F6%C7%D0&nPage=1&nPageSize=0&sort_order=&textkey=&textword="
get_hunjang(url1,1)
# Out:
# [{'academy_name': '정상어학원 성동분원',
#   'title': '어학원 초중선생님 및 사무직원  초빙',
#   'local': '서울\xa0성동구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '09.18'},
#  {'academy_name': '삼광학원',
#   'title': '급구: 초등부 영어/고등부영어/중등부수학 선생님을 모십니다.',
#   'local': '경기\xa0의정부',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '10.02'},
#  {'academy_name': '하이퍼리뷰학원',
#   'title': '대치동 하이퍼리뷰학원. 국어 고등부/재수생 강사 모집',
#   'local': '서울\xa0강남구',
#   'subject': '국어',
#   'start_date': '09.13',
#   'end_date': '09.27'},
#  {'academy_name': '마테마타수학학원',
#   'title': '[초등부] 연 3000이상 보장',
#   'local': '경기\xa0고양시',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '09.25'},
#  {'academy_name': '유라영어학원',
#   'title': '광명시 철산동 영어전문학원 입니다~~~~~^^!!.',
#   'local': '경기\xa0광명시',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': '매쓰블릭수학학원',
#   'title': '초중등부 수학 전임선생님을 모십니다.',
#   'local': '인천\xa0부평구',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '09.26'},
#  {'academy_name': '백선화수학학원',
#   'title': '열정적인 초중등부/중고등부 선생님을 모십니다주5일 가능)',
#   'local': '경기\xa0성남시',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '오세용 어학원',
#   'title': '초중등부 영어선생님(전임/주5일 근무)',
#   'local': '서울\xa0송파구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '10.06'},
#  {'academy_name': '강한수학학원',
#   'title': '중등부 화목토 파트 수학선생님을 모십니다.',
#   'local': '경기\xa0남양주',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '나무아카데미',
#   'title': '2021년도 수능, 내신 집필진 모집 (국어 내근)',
#   'local': '서울\xa0강남구',
#   'subject': '국어',
#   'start_date': '09.13',
#   'end_date': '09.23'}]

# %%
url2="https://www.hunjang.com/adopt/adopt_total_list.asp?schSubject=01&schSubject_name=%B1%B9%BE%EE&schSubject=02&schSubject_name=%BF%B5%BE%EE&schSubject=03&schSubject_name=%BC%F6%C7%D0&nPage=2&nPageSize=20&sort_order=&textkey=&textword="
get_hunjang(url2,2)
# Out:
# [{'academy_name': '수학의힘 강동 본원',
#   'title': '\n영어 수학 선생님을 모십니다',
#   'local': '서울\xa0강동구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': '뉴욕센트럴영어학원',
#   'title': '\n김포 고촌 뉴욕센트럴영어학원 초중등 강사 모집',
#   'local': '경기\xa0김포시',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '09.16'},
#  {'academy_name': '김정은 수학',
#   'title': '\n김정은수학 더퍼스트 영등포 신길관 수학강사 모집',
#   'local': '서울\xa0영등포',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '10.09'},
#  {'academy_name': '엠케이수학',
#   'title': '\n중등~고1 영어 선생님 모십니다',
#   'local': '서울\xa0강북구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '필탑학원',
#   'title': '\n수학(중3~고2.주5일)전임.초빙',
#   'local': '서울\xa0구로구',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': '일공구오국어학원',
#   'title': '\n가온국어 논술 학원에서 중등부 선생님을 모십니다.',
#   'local': '서울\xa0광진구',
#   'subject': '국어',
#   'start_date': '09.13',
#   'end_date': '10.01'},
#  {'academy_name': '황은영국어 2관',
#   'title': '\n동탄 중고등부 국어 과학 선생님 모십니다',
#   'local': '경기\xa0화성시',
#   'subject': '국어',
#   'start_date': '09.13',
#   'end_date': '10.12'},
#  {'academy_name': '온새미로입시학원',
#   'title': '\n국어. 영어.수학  선생님을 모집합니다.',
#   'local': '경기\xa0파주시',
#   'subject': '국어',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '아이필학원',
#   'title': '\n중고등 국어강사 모십니다',
#   'local': '인천\xa0계양구',
#   'subject': '국어',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '대두수학학원',
#   'title': '\n국어 강사님을 모십니다.',
#   'local': '경기\xa0성남시',
#   'subject': '국어',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': '김샘수학&유베스타어학원',
#   'title': '\n연수UbestA영어학원 초중등부영어선생님 모십니다.',
#   'local': '인천\xa0연수구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '신수학영어학원',
#   'title': '\n열정으로 가득하신 고등부 영어 파트 선생님 모십니다^^',
#   'local': '인천\xa0남동구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': '고대수학원',
#   'title': '\n고대수학원 중고등전임1명,초등월수금,화목파트1명 모집',
#   'local': '인천\xa0연수구',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '와이즈만영재교육 잠실센...',
#   'title': '\n실험 과학 및 사고력 수학 선생님과 데스크 선생님을 모십니다.',
#   'local': '서울\xa0송파구',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': 'Julie 영어수학',
#   'title': '\n초중등 영어 선생님 모십니다. 어학원 경력자 우대',
#   'local': '서울\xa0중랑구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '10.13'},
#  {'academy_name': '주식회사 교연학원/LFA키...',
#   'title': '\n중/고등 영어.수학.국어 선생님 모십니다^^',
#   'local': '인천\xa0서구',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '10.08'},
#  {'academy_name': '탑 고려보습학원',
#   'title': '\n[광진구] [월수금] 중1 수학 선생님 모십니다.',
#   'local': '서울\xa0광진구',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '09.20'},
#  {'academy_name': '강북 세일학원',
#   'title': '\n(중등부) 수학 선생님을 모십니다',
#   'local': '서울\xa0성북구',
#   'subject': '수학',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': '채움학원',
#   'title': '\n[경기 부천시] [전임] [월~토] [중1~고2 영어]',
#   'local': '경기\xa0부천시',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '채용시'},
#  {'academy_name': '대학입시외국어학원',
#   'title': '\n단과!열정!초중 관리자 중고 영/수/과학샘 /전문경영인 환영',
#   'local': '경기\xa0시흥시',
#   'subject': '영어',
#   'start_date': '09.13',
#   'end_date': '10.10'}]

# %%
import pandas as pd
from urllib.parse import urlencode,quote
from datetime import datetime

today_date = datetime.today().strftime("%Y-%m-%d")

df_fin = pd.DataFrame()
for pg in range(1,31): #마지막페이지30
    url = "https://www.hunjang.com/adopt/adopt_total_list.asp?schSubject=01&schSubject_name=%B1%B9%BE%EE&schSubject=02&schSubject_name=%BF%B5%BE%EE&schSubject=03&schSubject_name=%BC%F6%C7%D0&nPage="+str(pg)+"&nPageSize=0&sort_order=&textkey=&textword="
    data_list = get_hunjang(url,pg)
    
    df = pd.DataFrame(data_list,columns=['academy_name','title','local','subject','start_date','end_date'])
    df_fin = pd.concat([df_fin,df],axis=0,ignore_index=True)

#df_fin.head()
filename = today_date+'-hunjang_crawling.csv'  
df_fin.to_csv('./'+filename,encoding='utf-8-sig')
